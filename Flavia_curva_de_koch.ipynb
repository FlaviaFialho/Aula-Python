# %% [markdown]
# <a href="https://colab.research.google.com/github/FlaviaFialho/Aula-Python/blob/master/Flavia_curva_de_koch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício: A curva de Koch é um fractal que parece com o da figura abaixo. Para desenhar uma curva de Koch com o comprimento x, tudo o que você tem que fazer é:
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
# 2. Vire 60 graus à esquerda.
#
# 3. Desenhe uma curva de Koch com o comprimento x/3.
#
# 4. Vire 120 graus à direita.
#
# 5. Desenhe uma curva de Koch com o comprimento x/3.
#
# 6. Vire 60 graus à esquerda.
#
# 7. Desenhe uma curva de Koch com o comprimento x/3.
#
# A exceção é se x for menor que 3: neste caso, você pode desenhar apenas uma linha reta com o comprimento x.
#
# a) Escreva uma função chamada koch que receba um ColabTurtle (ou turtle) e um comprimento como parâmetros, e use o ColabTurtle para desenhar uma curva de Koch com o comprimento dado.
#
# b) Escreva uma função chamada snowflake que desenhe três curvas de Koch para fazer o traçado de um floco de neve.
#
# c) A curva de Koch pode ser generalizada de vários modos. Veja exemplos em http://en.wikipedia.org/wiki/Koch_snowflake e implemente o seu favorito.

# %%
# !pip3 install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading https://files.pythonhosted.org/packages/49/01/6da7091c2c6c917cce99c000b89acb6aa27b66ef6eafc0c0ccf59b98694f/ColabTurtle-2.0.0.tar.gz
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.0.0-cp36-none-any.whl size=4032 sha256=d9960d97b379bca9c46b418cc0cb9f26a534e13d857569f0daabfdba7e543bde
#   Stored in directory: /root/.cache/pip/wheels/a8/29/ec/ad346f0042ae467cc74f4378916348faf975b07890651dcae7
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.0.0

# %%
import ColabTurtle

# %%
import ColabTurtle.Turtle as turt 
turt.initializeTurtle(initial_speed=10)
turt.color("red")
turt.bgcolor("yellow")
turt.width(2) #grossura da linha

def koch(turt, x):
  if x < 10:
    turt.forward(5)
    return
  n = x/3
  koch(turt, n)
  turt.left(60)
  koch(turt, n)
  turt.right(120)
  koch(turt, n)
  turt.left(60)
  koch(turt, n)

def snowflake(turt, n):
  for i in range(3):
    koch(turt, n)
    turt.right(120)

turt.penup()
turt.goto(300, 450) #centraliza a figura
turt.pendown()
snowflake(turt, 600)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="yellow"/>
#         <line x1="300" y1="450" x2="300.0" y2="445.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="300.0" y1="445.0" x2="295.6698729810778" y2="442.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="295.6698729810778" y1="442.5" x2="300.0" y2="440.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="300.0" y1="440.0" x2="300.0" y2="435.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="300.0" y1="435.0" x2="295.6698729810778" y2="432.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="295.6698729810778" y1="432.5" x2="291.3397459621556" y2="435.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="291.3397459621556" y1="435.0" x2="291.3397459621556" y2="430.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="291.3397459621556" y1="430.0" x2="287.00961894323336" y2="427.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="287.00961894323336" y1="427.5" x2="291.3397459621556" y2="425.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="291.3397459621556" y1="425.0" x2="291.3397459621556" y2="420.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="291.3397459621556" y1="420.0" x2="295.6698729810778" y2="422.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="295.6698729810778" y1="422.5" x2="300.0" y2="420.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="300.0" y1="420.0" x2="300.0" y2="415.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="300.0" y1="415.0" x2="295.6698729810778" y2="412.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="295.6698729810778" y1="412.5" x2="300.0" y2="410.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="300.0" y1="410.0" x2="300.0" y2="405.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="300.0" y1="405.0" x2="295.6698729810778" y2="402.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="295.6698729810778" y1="402.5" x2="291.3397459621556" y2="405.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="291.3397459621556" y1="405.0" x2="291.3397459621556" y2="400.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="291.3397459621556" y1="400.0" x2="287.00961894323336" y2="397.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="287.00961894323336" y1="397.5" x2="282.67949192431115" y2="400.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="282.67949192431115" y1="400.0" x2="282.67949192431115" y2="405.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="282.67949192431115" y1="405.0" x2="278.34936490538894" y2="402.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="278.34936490538894" y1="402.5" x2="274.0192378864667" y2="405.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="274.0192378864667" y1="405.0" x2="274.0192378864667" y2="400.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="274.0192378864667" y1="400.0" x2="269.6891108675445" y2="397.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="269.6891108675445" y1="397.5" x2="274.0192378864667" y2="395.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="274.0192378864667" y1="395.0" x2="274.0192378864667" y2="390.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="274.0192378864667" y1="390.0" x2="269.6891108675445" y2="387.5" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="269.6891108675445" y1="387.5" x2="265.3589838486223" y2="390.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="265.3589838486223" y1="390.0" x2="265.3589838486223" y2="385.0" stroke-linecap="round" style="stroke:red;stroke-width:2"/><line x1="265.3589838486223" y1="385.0" x2="261.0288568297001" y2="382.5"  ...
